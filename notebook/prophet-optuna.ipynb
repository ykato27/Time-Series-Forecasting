# %% [markdown]
# ## Prophetでoptunaでパラメータチューニングを行う

# %%
# ライブラリーのインポート
import pandas as pd
import numpy as np
import seaborn as sns
import optuna
from matplotlib import pylab as plt
# %matplotlib inline

from fbprophet import Prophet
from fbprophet.plot import add_changepoints_to_plot

import warnings
warnings.filterwarnings("ignore")

# %%
# https://stat.ethz.ch/R-manual/R-devel/library/datasets/html/AirPassengers.html
df = pd.read_csv('../data/AirPassengers.csv')

# float型に変換
df['#Passengers'] = df['#Passengers'].astype('float64')
df = df.rename(columns={'#Passengers': 'Passengers'})

# datetime型に変換にする
df.Month = pd.to_datetime(df.Month)

# データの中身を確認
df.head()
# Out:
#        Month  Passengers
# 0 1949-01-01       112.0
# 1 1949-02-01       118.0
# 2 1949-03-01       132.0
# 3 1949-04-01       129.0
# 4 1949-05-01       121.0

# %%
fig, ax = plt.subplots()
a = sns.lineplot(x="Month", y="Passengers", data=df)
plt.show()

# %% [markdown]
# ## Prophetでモデルを構築する
# - optunaでハイパラチューニングを行う

# %%
def objective_variable(train, valid):

    def objective(trial):
            params = {
                    'changepoint_range' : trial.suggest_discrete_uniform('changepoint_range', 0.8, 0.95, 0.001),
                    'n_changepoints' : trial.suggest_int('n_changepoints', 20, 35),
                    'changepoint_prior_scale' : trial.suggest_discrete_uniform('changepoint_prior_scale',0.001, 0.5, 0.001),
                    'seasonality_prior_scale' : trial.suggest_discrete_uniform('seasonality_prior_scale',1, 25, 0.1),
            }
            
            # fit_model
            model = Prophet(
                changepoint_range = params['changepoint_prior_scale'],
                n_changepoints=params['n_changepoints'],
                changepoint_prior_scale=params['changepoint_prior_scale'],
                seasonality_prior_scale = params['seasonality_prior_scale'],
            )

            model.fit(train)
            future = model.make_future_dataframe(periods=len(valid))

            forecast = model.predict(future)
            valid_forecast = forecast.tail(len(valid))

            val_mape = np.mean(np.abs((valid_forecast.yhat-valid.y)/valid.y))*100

            return val_mape

    return objective

def optuna_parameter(train, valid):
    study = optuna.create_study(sampler=optuna.samplers.RandomSampler(seed=10))
    study.optimize(objective_variable(train, valid), timeout=500)
    optuna_best_params = study.best_params

    return study

# %%
# %%time
df = df.rename(columns={'Month':'ds','Passengers':'y'})
df = df[['ds','y']]
df_train = df[df['ds'] < '1956-04-01']
df_valid = df[(df['ds'] >= '1956-04-01')&(df['ds'] < '1957-04-01')]
df_test = df[df['ds'] >= '1957-04-01']

study = optuna_parameter(df_train, df_valid)
# Out:
# [I 2021-05-16 04:28:38,633] A new study created in memory with name: no-name-d5708f39-2c46-40ae-ac51-ab827572b093
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:28:48,079] Trial 0 finished with value: 9.96700911372791 and parameters: {'changepoint_range': 0.916, 'n_changepoints': 20, 'changepoint_prior_scale': 0.317, 'seasonality_prior_scale': 19.0}. Best is trial 0 with value: 9.96700911372791.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2021-05-16 04:28:52,150] Trial 1 finished with value: 10.159879227020268 and parameters: {'changepoint_range': 0.875, 'n_changepoints': 23, 'changepoint_prior_scale': 0.1, 'seasonality_prior_scale': 19.3}. Best is trial 0 with value: 9.96700911372791.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:28:59,654] Trial 2 finished with value: 9.964264416131112 and parameters: {'changepoint_range': 0.8250000000000001, 'n_changepoints': 21, 'changepoint_prior_scale': 0.343, 'seasonality_prior_scale': 23.900000000000002}. Best is trial 2 with value: 9.964264416131112.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:29:07,369] Trial 3 finished with value: 10.016355719930448 and parameters: {'changepoint_range': 0.8, 'n_changepoints': 28, 'changepoint_prior_scale': 0.40700000000000003, 'seasonality_prior_scale': 15.700000000000001}. Best is trial 2 with value: 9.964264416131112.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:29:13,020] Trial 4 finished with value: 9.914697016560876 and parameters: {'changepoint_range': 0.908, 'n_changepoints': 24, 'changepoint_prior_scale': 0.459, 'seasonality_prior_scale': 18.2}. Best is trial 4 with value: 9.914697016560876.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 15.
# [I 2021-05-16 04:29:18,207] Trial 5 finished with value: 9.833067023204261 and parameters: {'changepoint_range': 0.881, 'n_changepoints': 22, 'changepoint_prior_scale': 0.187, 'seasonality_prior_scale': 17.2}. Best is trial 5 with value: 9.833067023204261.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 25.
# [I 2021-05-16 04:29:23,436] Trial 6 finished with value: 9.965213290366963 and parameters: {'changepoint_range': 0.8660000000000001, 'n_changepoints': 26, 'changepoint_prior_scale': 0.309, 'seasonality_prior_scale': 13.3}. Best is trial 5 with value: 9.833067023204261.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:29:31,292] Trial 7 finished with value: 10.017192077007726 and parameters: {'changepoint_range': 0.898, 'n_changepoints': 29, 'changepoint_prior_scale': 0.403, 'seasonality_prior_scale': 13.5}. Best is trial 5 with value: 9.833067023204261.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 3.
# [I 2021-05-16 04:29:34,685] Trial 8 finished with value: 10.107177680152517 and parameters: {'changepoint_range': 0.937, 'n_changepoints': 25, 'changepoint_prior_scale': 0.046, 'seasonality_prior_scale': 8.2}. Best is trial 5 with value: 9.833067023204261.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 1.
# [I 2021-05-16 04:29:38,010] Trial 9 finished with value: 10.102174376376725 and parameters: {'changepoint_range': 0.8170000000000001, 'n_changepoints': 33, 'changepoint_prior_scale': 0.024, 'seasonality_prior_scale': 16.0}. Best is trial 5 with value: 9.833067023204261.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2021-05-16 04:29:41,748] Trial 10 finished with value: 10.155092066101727 and parameters: {'changepoint_range': 0.882, 'n_changepoints': 33, 'changepoint_prior_scale': 0.1, 'seasonality_prior_scale': 21.6}. Best is trial 5 with value: 9.833067023204261.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 11.
# [I 2021-05-16 04:29:46,455] Trial 11 finished with value: 9.87168782931101 and parameters: {'changepoint_range': 0.8530000000000001, 'n_changepoints': 32, 'changepoint_prior_scale': 0.148, 'seasonality_prior_scale': 22.3}. Best is trial 5 with value: 9.833067023204261.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 16.
# [I 2021-05-16 04:29:51,209] Trial 12 finished with value: 9.834825646668742 and parameters: {'changepoint_range': 0.8490000000000001, 'n_changepoints': 22, 'changepoint_prior_scale': 0.197, 'seasonality_prior_scale': 3.2}. Best is trial 5 with value: 9.833067023204261.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 15.
# [I 2021-05-16 04:29:56,364] Trial 13 finished with value: 9.832607272382717 and parameters: {'changepoint_range': 0.923, 'n_changepoints': 22, 'changepoint_prior_scale': 0.193, 'seasonality_prior_scale': 23.700000000000003}. Best is trial 13 with value: 9.832607272382717.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:30:01,884] Trial 14 finished with value: 9.943384602156037 and parameters: {'changepoint_range': 0.9490000000000001, 'n_changepoints': 27, 'changepoint_prior_scale': 0.41400000000000003, 'seasonality_prior_scale': 7.0}. Best is trial 13 with value: 9.832607272382717.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 22.
# [I 2021-05-16 04:30:06,972] Trial 15 finished with value: 9.924488839027322 and parameters: {'changepoint_range': 0.89, 'n_changepoints': 34, 'changepoint_prior_scale': 0.268, 'seasonality_prior_scale': 15.200000000000001}. Best is trial 13 with value: 9.832607272382717.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 2.
# [I 2021-05-16 04:30:10,287] Trial 16 finished with value: 10.102213040425674 and parameters: {'changepoint_range': 0.805, 'n_changepoints': 25, 'changepoint_prior_scale': 0.04, 'seasonality_prior_scale': 8.3}. Best is trial 13 with value: 9.832607272382717.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 0.
# [I 2021-05-16 04:30:13,631] Trial 17 finished with value: 10.094620844906157 and parameters: {'changepoint_range': 0.8490000000000001, 'n_changepoints': 32, 'changepoint_prior_scale': 0.02, 'seasonality_prior_scale': 11.3}. Best is trial 13 with value: 9.832607272382717.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 14.
# [I 2021-05-16 04:30:19,395] Trial 18 finished with value: 9.767208633388739 and parameters: {'changepoint_range': 0.8470000000000001, 'n_changepoints': 30, 'changepoint_prior_scale': 0.17400000000000002, 'seasonality_prior_scale': 2.0}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:30:25,444] Trial 19 finished with value: 9.924182963215351 and parameters: {'changepoint_range': 0.932, 'n_changepoints': 32, 'changepoint_prior_scale': 0.44, 'seasonality_prior_scale': 11.0}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 25.
# [I 2021-05-16 04:30:30,533] Trial 20 finished with value: 9.942787521807704 and parameters: {'changepoint_range': 0.891, 'n_changepoints': 28, 'changepoint_prior_scale': 0.299, 'seasonality_prior_scale': 7.300000000000001}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 12.
# [I 2021-05-16 04:30:34,733] Trial 21 finished with value: 9.833132159055411 and parameters: {'changepoint_range': 0.8450000000000001, 'n_changepoints': 20, 'changepoint_prior_scale': 0.152, 'seasonality_prior_scale': 6.800000000000001}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 19.
# [I 2021-05-16 04:30:39,483] Trial 22 finished with value: 9.888861079937906 and parameters: {'changepoint_range': 0.884, 'n_changepoints': 29, 'changepoint_prior_scale': 0.23800000000000002, 'seasonality_prior_scale': 8.0}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 13.
# [I 2021-05-16 04:30:43,941] Trial 23 finished with value: 9.825118116865195 and parameters: {'changepoint_range': 0.809, 'n_changepoints': 35, 'changepoint_prior_scale': 0.17, 'seasonality_prior_scale': 12.9}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 12.
# [I 2021-05-16 04:30:48,287] Trial 24 finished with value: 9.827620780679041 and parameters: {'changepoint_range': 0.9470000000000001, 'n_changepoints': 27, 'changepoint_prior_scale': 0.16, 'seasonality_prior_scale': 13.5}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 2.
# [I 2021-05-16 04:30:51,651] Trial 25 finished with value: 10.101276596917904 and parameters: {'changepoint_range': 0.887, 'n_changepoints': 33, 'changepoint_prior_scale': 0.035, 'seasonality_prior_scale': 12.100000000000001}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 24.
# [I 2021-05-16 04:30:58,509] Trial 26 finished with value: 9.859715416325127 and parameters: {'changepoint_range': 0.918, 'n_changepoints': 31, 'changepoint_prior_scale': 0.294, 'seasonality_prior_scale': 1.8}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 12.
# [I 2021-05-16 04:31:02,548] Trial 27 finished with value: 9.833598486441165 and parameters: {'changepoint_range': 0.8520000000000001, 'n_changepoints': 29, 'changepoint_prior_scale': 0.15, 'seasonality_prior_scale': 13.3}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 1.
# [I 2021-05-16 04:31:05,776] Trial 28 finished with value: 10.102076863868902 and parameters: {'changepoint_range': 0.901, 'n_changepoints': 22, 'changepoint_prior_scale': 0.026000000000000002, 'seasonality_prior_scale': 9.1}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:31:11,612] Trial 29 finished with value: 9.951086026829497 and parameters: {'changepoint_range': 0.8160000000000001, 'n_changepoints': 22, 'changepoint_prior_scale': 0.443, 'seasonality_prior_scale': 9.8}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 3.
# [I 2021-05-16 04:31:14,847] Trial 30 finished with value: 10.10227478913115 and parameters: {'changepoint_range': 0.8330000000000001, 'n_changepoints': 32, 'changepoint_prior_scale': 0.054, 'seasonality_prior_scale': 18.900000000000002}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 5.
# [I 2021-05-16 04:31:18,357] Trial 31 finished with value: 10.102364936940372 and parameters: {'changepoint_range': 0.8700000000000001, 'n_changepoints': 29, 'changepoint_prior_scale': 0.074, 'seasonality_prior_scale': 5.4}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 9.
# [I 2021-05-16 04:31:22,133] Trial 32 finished with value: 10.12544661863597 and parameters: {'changepoint_range': 0.897, 'n_changepoints': 20, 'changepoint_prior_scale': 0.125, 'seasonality_prior_scale': 14.0}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:31:28,594] Trial 33 finished with value: 9.909503549958593 and parameters: {'changepoint_range': 0.8340000000000001, 'n_changepoints': 26, 'changepoint_prior_scale': 0.462, 'seasonality_prior_scale': 23.3}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using -1.
# [I 2021-05-16 04:31:31,611] Trial 34 finished with value: 10.102456826775242 and parameters: {'changepoint_range': 0.885, 'n_changepoints': 28, 'changepoint_prior_scale': 0.008, 'seasonality_prior_scale': 24.5}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 23.
# [I 2021-05-16 04:31:37,540] Trial 35 finished with value: 9.92380274503829 and parameters: {'changepoint_range': 0.886, 'n_changepoints': 32, 'changepoint_prior_scale': 0.281, 'seasonality_prior_scale': 22.1}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 5.
# [I 2021-05-16 04:31:40,889] Trial 36 finished with value: 10.099322851010623 and parameters: {'changepoint_range': 0.888, 'n_changepoints': 31, 'changepoint_prior_scale': 0.075, 'seasonality_prior_scale': 11.3}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 18.
# [I 2021-05-16 04:31:45,629] Trial 37 finished with value: 9.867934600399765 and parameters: {'changepoint_range': 0.904, 'n_changepoints': 21, 'changepoint_prior_scale': 0.22, 'seasonality_prior_scale': 5.0}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 3.
# [I 2021-05-16 04:31:49,054] Trial 38 finished with value: 10.102305114030612 and parameters: {'changepoint_range': 0.876, 'n_changepoints': 33, 'changepoint_prior_scale': 0.046, 'seasonality_prior_scale': 20.200000000000003}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2021-05-16 04:31:52,692] Trial 39 finished with value: 10.158635295968006 and parameters: {'changepoint_range': 0.885, 'n_changepoints': 29, 'changepoint_prior_scale': 0.1, 'seasonality_prior_scale': 11.5}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 0.
# [I 2021-05-16 04:31:55,774] Trial 40 finished with value: 10.102004630020337 and parameters: {'changepoint_range': 0.8440000000000001, 'n_changepoints': 20, 'changepoint_prior_scale': 0.016, 'seasonality_prior_scale': 11.9}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 15.
# [I 2021-05-16 04:32:00,677] Trial 41 finished with value: 9.831486117739711 and parameters: {'changepoint_range': 0.912, 'n_changepoints': 28, 'changepoint_prior_scale': 0.193, 'seasonality_prior_scale': 5.0}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:32:07,503] Trial 42 finished with value: 10.008532112091277 and parameters: {'changepoint_range': 0.926, 'n_changepoints': 29, 'changepoint_prior_scale': 0.392, 'seasonality_prior_scale': 21.400000000000002}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 25.
# [I 2021-05-16 04:32:14,569] Trial 43 finished with value: 9.964295309117416 and parameters: {'changepoint_range': 0.891, 'n_changepoints': 32, 'changepoint_prior_scale': 0.308, 'seasonality_prior_scale': 1.5}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 19.
# [I 2021-05-16 04:32:21,802] Trial 44 finished with value: 9.873036748558894 and parameters: {'changepoint_range': 0.913, 'n_changepoints': 22, 'changepoint_prior_scale': 0.23, 'seasonality_prior_scale': 13.3}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 6.
# [I 2021-05-16 04:32:25,265] Trial 45 finished with value: 10.094072908685742 and parameters: {'changepoint_range': 0.873, 'n_changepoints': 33, 'changepoint_prior_scale': 0.08800000000000001, 'seasonality_prior_scale': 1.3}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 18.
# [I 2021-05-16 04:32:30,153] Trial 46 finished with value: 9.886941304691742 and parameters: {'changepoint_range': 0.928, 'n_changepoints': 31, 'changepoint_prior_scale': 0.229, 'seasonality_prior_scale': 11.0}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 3.
# [I 2021-05-16 04:32:33,480] Trial 47 finished with value: 10.103087467520233 and parameters: {'changepoint_range': 0.8170000000000001, 'n_changepoints': 25, 'changepoint_prior_scale': 0.048, 'seasonality_prior_scale': 18.2}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:32:38,608] Trial 48 finished with value: 9.947307425161757 and parameters: {'changepoint_range': 0.811, 'n_changepoints': 23, 'changepoint_prior_scale': 0.28700000000000003, 'seasonality_prior_scale': 8.0}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 14.
# [I 2021-05-16 04:32:43,510] Trial 49 finished with value: 9.766385209386987 and parameters: {'changepoint_range': 0.899, 'n_changepoints': 32, 'changepoint_prior_scale': 0.17600000000000002, 'seasonality_prior_scale': 3.2}. Best is trial 49 with value: 9.766385209386987.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 16.
# [I 2021-05-16 04:32:48,899] Trial 50 finished with value: 9.834281748182887 and parameters: {'changepoint_range': 0.922, 'n_changepoints': 32, 'changepoint_prior_scale': 0.197, 'seasonality_prior_scale': 21.8}. Best is trial 49 with value: 9.766385209386987.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:32:54,173] Trial 51 finished with value: 9.996682702112373 and parameters: {'changepoint_range': 0.8570000000000001, 'n_changepoints': 24, 'changepoint_prior_scale': 0.41500000000000004, 'seasonality_prior_scale': 18.7}. Best is trial 49 with value: 9.766385209386987.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 8.
# [I 2021-05-16 04:32:58,291] Trial 52 finished with value: 10.12129864695254 and parameters: {'changepoint_range': 0.876, 'n_changepoints': 30, 'changepoint_prior_scale': 0.107, 'seasonality_prior_scale': 22.5}. Best is trial 49 with value: 9.766385209386987.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:33:04,015] Trial 53 finished with value: 10.016066574938197 and parameters: {'changepoint_range': 0.9450000000000001, 'n_changepoints': 25, 'changepoint_prior_scale': 0.433, 'seasonality_prior_scale': 8.4}. Best is trial 49 with value: 9.766385209386987.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2021-05-16 04:33:07,724] Trial 54 finished with value: 10.143085155432479 and parameters: {'changepoint_range': 0.803, 'n_changepoints': 20, 'changepoint_prior_scale': 0.093, 'seasonality_prior_scale': 2.6}. Best is trial 49 with value: 9.766385209386987.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 18.
# [I 2021-05-16 04:33:12,743] Trial 55 finished with value: 9.878209263684552 and parameters: {'changepoint_range': 0.8380000000000001, 'n_changepoints': 34, 'changepoint_prior_scale': 0.229, 'seasonality_prior_scale': 4.1}. Best is trial 49 with value: 9.766385209386987.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 0.
# [I 2021-05-16 04:33:15,880] Trial 56 finished with value: 10.103338073972257 and parameters: {'changepoint_range': 0.922, 'n_changepoints': 26, 'changepoint_prior_scale': 0.013000000000000001, 'seasonality_prior_scale': 21.6}. Best is trial 49 with value: 9.766385209386987.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 14.
# [I 2021-05-16 04:33:20,717] Trial 57 finished with value: 9.76545938581077 and parameters: {'changepoint_range': 0.8410000000000001, 'n_changepoints': 31, 'changepoint_prior_scale': 0.178, 'seasonality_prior_scale': 20.1}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 23.
# [I 2021-05-16 04:33:26,921] Trial 58 finished with value: 9.95270183428893 and parameters: {'changepoint_range': 0.927, 'n_changepoints': 28, 'changepoint_prior_scale': 0.28, 'seasonality_prior_scale': 3.9000000000000004}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 21.
# [I 2021-05-16 04:33:31,543] Trial 59 finished with value: 9.935817887794347 and parameters: {'changepoint_range': 0.8570000000000001, 'n_changepoints': 26, 'changepoint_prior_scale': 0.256, 'seasonality_prior_scale': 22.400000000000002}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:33:38,533] Trial 60 finished with value: 10.015764628171182 and parameters: {'changepoint_range': 0.8450000000000001, 'n_changepoints': 26, 'changepoint_prior_scale': 0.397, 'seasonality_prior_scale': 10.9}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 23.
# [I 2021-05-16 04:33:44,476] Trial 61 finished with value: 9.92740952123417 and parameters: {'changepoint_range': 0.8270000000000001, 'n_changepoints': 33, 'changepoint_prior_scale': 0.28500000000000003, 'seasonality_prior_scale': 2.4000000000000004}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:33:50,909] Trial 62 finished with value: 9.946076785070423 and parameters: {'changepoint_range': 0.9490000000000001, 'n_changepoints': 23, 'changepoint_prior_scale': 0.308, 'seasonality_prior_scale': 9.8}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:33:58,005] Trial 63 finished with value: 9.94250938202026 and parameters: {'changepoint_range': 0.921, 'n_changepoints': 30, 'changepoint_prior_scale': 0.41100000000000003, 'seasonality_prior_scale': 7.9}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:34:02,963] Trial 64 finished with value: 9.878713340496049 and parameters: {'changepoint_range': 0.8410000000000001, 'n_changepoints': 29, 'changepoint_prior_scale': 0.47000000000000003, 'seasonality_prior_scale': 18.0}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 19.
# [I 2021-05-16 04:34:07,872] Trial 65 finished with value: 9.873043655633996 and parameters: {'changepoint_range': 0.8390000000000001, 'n_changepoints': 21, 'changepoint_prior_scale': 0.23, 'seasonality_prior_scale': 24.400000000000002}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 1.
# [I 2021-05-16 04:34:10,880] Trial 66 finished with value: 10.102111267172216 and parameters: {'changepoint_range': 0.902, 'n_changepoints': 23, 'changepoint_prior_scale': 0.024, 'seasonality_prior_scale': 23.900000000000002}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:34:17,050] Trial 67 finished with value: 9.85501075749141 and parameters: {'changepoint_range': 0.929, 'n_changepoints': 33, 'changepoint_prior_scale': 0.482, 'seasonality_prior_scale': 15.4}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 3.
# [I 2021-05-16 04:34:20,364] Trial 68 finished with value: 10.100796411746895 and parameters: {'changepoint_range': 0.9400000000000001, 'n_changepoints': 22, 'changepoint_prior_scale': 0.057, 'seasonality_prior_scale': 9.9}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:34:26,149] Trial 69 finished with value: 9.967594242021628 and parameters: {'changepoint_range': 0.915, 'n_changepoints': 25, 'changepoint_prior_scale': 0.32, 'seasonality_prior_scale': 1.2}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:34:31,640] Trial 70 finished with value: 10.00848235484617 and parameters: {'changepoint_range': 0.882, 'n_changepoints': 25, 'changepoint_prior_scale': 0.45, 'seasonality_prior_scale': 23.6}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:34:36,932] Trial 71 finished with value: 10.015725895150373 and parameters: {'changepoint_range': 0.8580000000000001, 'n_changepoints': 26, 'changepoint_prior_scale': 0.449, 'seasonality_prior_scale': 2.4000000000000004}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 2.
# [I 2021-05-16 04:34:40,096] Trial 72 finished with value: 10.10231973991487 and parameters: {'changepoint_range': 0.861, 'n_changepoints': 22, 'changepoint_prior_scale': 0.044000000000000004, 'seasonality_prior_scale': 19.8}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:34:47,031] Trial 73 finished with value: 10.01376782926764 and parameters: {'changepoint_range': 0.8450000000000001, 'n_changepoints': 29, 'changepoint_prior_scale': 0.44, 'seasonality_prior_scale': 22.200000000000003}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 1.
# [I 2021-05-16 04:34:50,003] Trial 74 finished with value: 10.100699955941554 and parameters: {'changepoint_range': 0.89, 'n_changepoints': 30, 'changepoint_prior_scale': 0.029, 'seasonality_prior_scale': 8.100000000000001}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:34:55,804] Trial 75 finished with value: 10.00971506063436 and parameters: {'changepoint_range': 0.904, 'n_changepoints': 23, 'changepoint_prior_scale': 0.402, 'seasonality_prior_scale': 13.4}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 2.
# [I 2021-05-16 04:34:59,065] Trial 76 finished with value: 10.12002488561187 and parameters: {'changepoint_range': 0.914, 'n_changepoints': 22, 'changepoint_prior_scale': 0.042, 'seasonality_prior_scale': 12.600000000000001}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2021-05-16 04:35:02,396] Trial 77 finished with value: 10.162595221377863 and parameters: {'changepoint_range': 0.879, 'n_changepoints': 31, 'changepoint_prior_scale': 0.10300000000000001, 'seasonality_prior_scale': 17.1}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:35:07,125] Trial 78 finished with value: 9.872007337561568 and parameters: {'changepoint_range': 0.919, 'n_changepoints': 20, 'changepoint_prior_scale': 0.482, 'seasonality_prior_scale': 24.5}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 14.
# [I 2021-05-16 04:35:13,122] Trial 79 finished with value: 9.7684001346424 and parameters: {'changepoint_range': 0.883, 'n_changepoints': 21, 'changepoint_prior_scale': 0.17300000000000001, 'seasonality_prior_scale': 1.4}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 5.
# [I 2021-05-16 04:35:16,579] Trial 80 finished with value: 10.103053751719514 and parameters: {'changepoint_range': 0.92, 'n_changepoints': 23, 'changepoint_prior_scale': 0.07200000000000001, 'seasonality_prior_scale': 17.8}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 21.
# [I 2021-05-16 04:35:21,539] Trial 81 finished with value: 9.919460432444243 and parameters: {'changepoint_range': 0.808, 'n_changepoints': 24, 'changepoint_prior_scale': 0.256, 'seasonality_prior_scale': 24.900000000000002}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 25.
# [I 2021-05-16 04:35:27,908] Trial 82 finished with value: 9.957157125306484 and parameters: {'changepoint_range': 0.8220000000000001, 'n_changepoints': 27, 'changepoint_prior_scale': 0.301, 'seasonality_prior_scale': 3.3000000000000003}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 23.
# [I 2021-05-16 04:35:33,848] Trial 83 finished with value: 9.932688626144358 and parameters: {'changepoint_range': 0.8430000000000001, 'n_changepoints': 31, 'changepoint_prior_scale': 0.276, 'seasonality_prior_scale': 21.200000000000003}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:35:39,372] Trial 84 finished with value: 9.890393196043457 and parameters: {'changepoint_range': 0.887, 'n_changepoints': 22, 'changepoint_prior_scale': 0.308, 'seasonality_prior_scale': 22.3}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 21.
# [I 2021-05-16 04:35:44,485] Trial 85 finished with value: 9.910128706192351 and parameters: {'changepoint_range': 0.878, 'n_changepoints': 30, 'changepoint_prior_scale': 0.253, 'seasonality_prior_scale': 22.900000000000002}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 13.
# [I 2021-05-16 04:35:48,384] Trial 86 finished with value: 9.801809796256396 and parameters: {'changepoint_range': 0.8620000000000001, 'n_changepoints': 28, 'changepoint_prior_scale': 0.17200000000000001, 'seasonality_prior_scale': 4.1}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 25.
# [I 2021-05-16 04:35:53,471] Trial 87 finished with value: 9.960041289239696 and parameters: {'changepoint_range': 0.9, 'n_changepoints': 34, 'changepoint_prior_scale': 0.307, 'seasonality_prior_scale': 21.3}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using -1.
# [I 2021-05-16 04:35:56,546] Trial 88 finished with value: 10.102099397461185 and parameters: {'changepoint_range': 0.8320000000000001, 'n_changepoints': 34, 'changepoint_prior_scale': 0.005, 'seasonality_prior_scale': 6.4}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:36:02,548] Trial 89 finished with value: 9.985709050207243 and parameters: {'changepoint_range': 0.8190000000000001, 'n_changepoints': 34, 'changepoint_prior_scale': 0.456, 'seasonality_prior_scale': 15.0}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:36:07,973] Trial 90 finished with value: 10.011443147468084 and parameters: {'changepoint_range': 0.8130000000000001, 'n_changepoints': 21, 'changepoint_prior_scale': 0.386, 'seasonality_prior_scale': 18.6}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:36:13,627] Trial 91 finished with value: 9.936074554974011 and parameters: {'changepoint_range': 0.8130000000000001, 'n_changepoints': 25, 'changepoint_prior_scale': 0.387, 'seasonality_prior_scale': 4.1}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 10.
# [I 2021-05-16 04:36:17,667] Trial 92 finished with value: 9.94543640115293 and parameters: {'changepoint_range': 0.881, 'n_changepoints': 32, 'changepoint_prior_scale': 0.137, 'seasonality_prior_scale': 14.600000000000001}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 18.
# [I 2021-05-16 04:36:21,646] Trial 93 finished with value: 9.799270582110664 and parameters: {'changepoint_range': 0.871, 'n_changepoints': 28, 'changepoint_prior_scale': 0.221, 'seasonality_prior_scale': 17.7}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 0.
# [I 2021-05-16 04:36:25,506] Trial 94 finished with value: 10.104540903861748 and parameters: {'changepoint_range': 0.908, 'n_changepoints': 32, 'changepoint_prior_scale': 0.019000000000000003, 'seasonality_prior_scale': 17.3}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 04:36:31,125] Trial 95 finished with value: 9.960714171064687 and parameters: {'changepoint_range': 0.8720000000000001, 'n_changepoints': 21, 'changepoint_prior_scale': 0.308, 'seasonality_prior_scale': 21.1}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 1.
# [I 2021-05-16 04:36:34,676] Trial 96 finished with value: 10.099344462576209 and parameters: {'changepoint_range': 0.91, 'n_changepoints': 25, 'changepoint_prior_scale': 0.034, 'seasonality_prior_scale': 1.8}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 10.
# [I 2021-05-16 04:36:39,188] Trial 97 finished with value: 9.942684020551146 and parameters: {'changepoint_range': 0.884, 'n_changepoints': 22, 'changepoint_prior_scale': 0.134, 'seasonality_prior_scale': 6.6000000000000005}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 0.
# [I 2021-05-16 04:36:42,801] Trial 98 finished with value: 10.098957070071503 and parameters: {'changepoint_range': 0.802, 'n_changepoints': 22, 'changepoint_prior_scale': 0.017, 'seasonality_prior_scale': 24.6}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 17.
# [I 2021-05-16 04:36:48,621] Trial 99 finished with value: 9.850346619167205 and parameters: {'changepoint_range': 0.8540000000000001, 'n_changepoints': 33, 'changepoint_prior_scale': 0.20700000000000002, 'seasonality_prior_scale': 7.1000000000000005}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 28.
# [I 2021-05-16 04:36:54,905] Trial 100 finished with value: 9.961930557586482 and parameters: {'changepoint_range': 0.8350000000000001, 'n_changepoints': 32, 'changepoint_prior_scale': 0.336, 'seasonality_prior_scale': 18.0}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 18.
# [I 2021-05-16 04:36:59,010] Trial 101 finished with value: 9.799518264761165 and parameters: {'changepoint_range': 0.928, 'n_changepoints': 28, 'changepoint_prior_scale': 0.222, 'seasonality_prior_scale': 14.3}. Best is trial 57 with value: 9.76545938581077.
# CPU times: user 8min 9s, sys: 10.6 s, total: 8min 20s
# Wall time: 8min 20s

# %%
# fit_model
best_model = Prophet(
    changepoint_range = study.best_params['changepoint_prior_scale'],
    n_changepoints=study.best_params['n_changepoints'],
    seasonality_prior_scale = study.best_params['seasonality_prior_scale'],
    changepoint_prior_scale=study.best_params['changepoint_prior_scale'],
)

# %%
best_model.fit(df_train)
feature_test = best_model.make_future_dataframe(periods=len(df_valid)+len(df_test), freq='M')

forecast_test = best_model.predict(feature_test)
forecast_test_plot = best_model.plot(forecast_test)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 14.

# %%
fig, ax = plt.subplots()
df.y.plot(ax=ax, label='Original', linestyle="dashed")
forecast_test.yhat.plot(ax=ax, label='Predict')
ax.legend()
