# %% [markdown]
# ## ProphetでCOVID-19をoptunaでパラメータチューニングを行う

# %%
# ライブラリーのインポート
import pandas as pd
import numpy as np
import seaborn as sns
import optuna
from matplotlib import pylab as plt
# %matplotlib inline

from fbprophet import Prophet
from fbprophet.plot import add_changepoints_to_plot

# 評価指標
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_log_error

import warnings
warnings.filterwarnings("ignore")

# %%
# https://stat.ethz.ch/R-manual/R-devel/library/datasets/html/AirPassengers.html
df = pd.read_csv('../data/AirPassengers.csv')

# float型に変換
df['#Passengers'] = df['#Passengers'].astype('float64')
df = df.rename(columns={'#Passengers': 'Passengers'})

# datetime型に変換にする
df.Month = pd.to_datetime(df.Month)

# データの中身を確認
df.head()
# Out:
#        Month  Passengers
# 0 1949-01-01       112.0
# 1 1949-02-01       118.0
# 2 1949-03-01       132.0
# 3 1949-04-01       129.0
# 4 1949-05-01       121.0

# %%
fig, ax = plt.subplots()
a = sns.lineplot(x="Month", y="Passengers", data=df)
plt.show()

# %% [markdown]
# ## Prophetでモデルを構築する
# - optunaでハイパラチューニングを行う

# %%
def objective_variable(train, valid):

    cap = int(np.percentile(train.y,95))
    floor = int(np.percentile(train.y,5))


    def objective(trial):
            params = {
                    'changepoint_range' : trial.suggest_discrete_uniform('changepoint_range', 0.8, 0.95, 0.001),
                    'n_changepoints' : trial.suggest_int('n_changepoints', 20, 35),
                    'changepoint_prior_scale' : trial.suggest_discrete_uniform('changepoint_prior_scale',0.001, 0.5, 0.001),
                    'seasonality_prior_scale' : trial.suggest_discrete_uniform('seasonality_prior_scale',1, 25, 0.1),
            }
            
            # fit_model
            model = Prophet(
                changepoint_range = params['changepoint_prior_scale'],
                n_changepoints=params['n_changepoints'],
                changepoint_prior_scale=params['changepoint_prior_scale'],
                seasonality_prior_scale = params['seasonality_prior_scale'],
            )

            model.fit(train)
            future = model.make_future_dataframe(periods=len(valid))

            forecast = model.predict(future)
            valid_forecast = forecast.tail(len(valid))

            val_mape = np.mean(np.abs((valid_forecast.yhat-valid.y)/valid.y))*100

            return val_mape

    return objective

def optuna_parameter(train, valid):
    study = optuna.create_study(sampler=optuna.samplers.RandomSampler(seed=10))
    study.optimize(objective_variable(train, valid), timeout=1000)
    optuna_best_params = study.best_params

    return study

# %%
# %%time
df = df.rename(columns={'Month':'ds','Passengers':'y'})
df = df[['ds','y']]
df_train = df[df['ds'] < '1956-04-01']
df_valid = df[(df['ds'] >= '1956-04-01')&(df['ds'] < '1957-04-01')]
df_test = df[df['ds'] >= '1957-04-01']

study = optuna_parameter(df_train, df_valid)
# Out:
# [I 2021-05-15 23:54:14,285] A new study created in memory with name: no-name-b6b3a1c1-0216-4af9-ae82-eae6049310fd
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-15 23:54:22,845] Trial 0 finished with value: 9.96700911372791 and parameters: {'changepoint_range': 0.916, 'n_changepoints': 20, 'changepoint_prior_scale': 0.317, 'seasonality_prior_scale': 19.0}. Best is trial 0 with value: 9.96700911372791.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2021-05-15 23:54:26,789] Trial 1 finished with value: 10.159879227020268 and parameters: {'changepoint_range': 0.875, 'n_changepoints': 23, 'changepoint_prior_scale': 0.1, 'seasonality_prior_scale': 19.3}. Best is trial 0 with value: 9.96700911372791.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-15 23:54:34,402] Trial 2 finished with value: 9.964264416131112 and parameters: {'changepoint_range': 0.8250000000000001, 'n_changepoints': 21, 'changepoint_prior_scale': 0.343, 'seasonality_prior_scale': 23.900000000000002}. Best is trial 2 with value: 9.964264416131112.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-15 23:54:42,754] Trial 3 finished with value: 10.016355719930448 and parameters: {'changepoint_range': 0.8, 'n_changepoints': 28, 'changepoint_prior_scale': 0.40700000000000003, 'seasonality_prior_scale': 15.700000000000001}. Best is trial 2 with value: 9.964264416131112.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-15 23:54:48,886] Trial 4 finished with value: 9.914697016560876 and parameters: {'changepoint_range': 0.908, 'n_changepoints': 24, 'changepoint_prior_scale': 0.459, 'seasonality_prior_scale': 18.2}. Best is trial 4 with value: 9.914697016560876.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 15.
# [I 2021-05-15 23:54:54,420] Trial 5 finished with value: 9.833067023204261 and parameters: {'changepoint_range': 0.881, 'n_changepoints': 22, 'changepoint_prior_scale': 0.187, 'seasonality_prior_scale': 17.2}. Best is trial 5 with value: 9.833067023204261.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 25.
# [I 2021-05-15 23:55:00,200] Trial 6 finished with value: 9.965213290366963 and parameters: {'changepoint_range': 0.8660000000000001, 'n_changepoints': 26, 'changepoint_prior_scale': 0.309, 'seasonality_prior_scale': 13.3}. Best is trial 5 with value: 9.833067023204261.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-15 23:55:09,425] Trial 7 finished with value: 10.017192077007726 and parameters: {'changepoint_range': 0.898, 'n_changepoints': 29, 'changepoint_prior_scale': 0.403, 'seasonality_prior_scale': 13.5}. Best is trial 5 with value: 9.833067023204261.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 3.
# [I 2021-05-15 23:55:13,257] Trial 8 finished with value: 10.107177680152517 and parameters: {'changepoint_range': 0.937, 'n_changepoints': 25, 'changepoint_prior_scale': 0.046, 'seasonality_prior_scale': 8.2}. Best is trial 5 with value: 9.833067023204261.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 1.
# [I 2021-05-15 23:55:16,846] Trial 9 finished with value: 10.102174376376725 and parameters: {'changepoint_range': 0.8170000000000001, 'n_changepoints': 33, 'changepoint_prior_scale': 0.024, 'seasonality_prior_scale': 16.0}. Best is trial 5 with value: 9.833067023204261.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2021-05-15 23:55:20,914] Trial 10 finished with value: 10.155092066101727 and parameters: {'changepoint_range': 0.882, 'n_changepoints': 33, 'changepoint_prior_scale': 0.1, 'seasonality_prior_scale': 21.6}. Best is trial 5 with value: 9.833067023204261.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 11.
# [I 2021-05-15 23:55:26,034] Trial 11 finished with value: 9.87168782931101 and parameters: {'changepoint_range': 0.8530000000000001, 'n_changepoints': 32, 'changepoint_prior_scale': 0.148, 'seasonality_prior_scale': 22.3}. Best is trial 5 with value: 9.833067023204261.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 16.
# [I 2021-05-15 23:55:31,242] Trial 12 finished with value: 9.834825646668742 and parameters: {'changepoint_range': 0.8490000000000001, 'n_changepoints': 22, 'changepoint_prior_scale': 0.197, 'seasonality_prior_scale': 3.2}. Best is trial 5 with value: 9.833067023204261.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 15.
# [I 2021-05-15 23:55:36,899] Trial 13 finished with value: 9.832607272382717 and parameters: {'changepoint_range': 0.923, 'n_changepoints': 22, 'changepoint_prior_scale': 0.193, 'seasonality_prior_scale': 23.700000000000003}. Best is trial 13 with value: 9.832607272382717.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-15 23:55:42,694] Trial 14 finished with value: 9.943384602156037 and parameters: {'changepoint_range': 0.9490000000000001, 'n_changepoints': 27, 'changepoint_prior_scale': 0.41400000000000003, 'seasonality_prior_scale': 7.0}. Best is trial 13 with value: 9.832607272382717.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 22.
# [I 2021-05-15 23:55:48,433] Trial 15 finished with value: 9.924488839027322 and parameters: {'changepoint_range': 0.89, 'n_changepoints': 34, 'changepoint_prior_scale': 0.268, 'seasonality_prior_scale': 15.200000000000001}. Best is trial 13 with value: 9.832607272382717.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 2.
# [I 2021-05-15 23:55:52,040] Trial 16 finished with value: 10.102213040425674 and parameters: {'changepoint_range': 0.805, 'n_changepoints': 25, 'changepoint_prior_scale': 0.04, 'seasonality_prior_scale': 8.3}. Best is trial 13 with value: 9.832607272382717.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 0.
# [I 2021-05-15 23:55:55,843] Trial 17 finished with value: 10.094620844906157 and parameters: {'changepoint_range': 0.8490000000000001, 'n_changepoints': 32, 'changepoint_prior_scale': 0.02, 'seasonality_prior_scale': 11.3}. Best is trial 13 with value: 9.832607272382717.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 14.
# [I 2021-05-15 23:56:02,598] Trial 18 finished with value: 9.767208633388739 and parameters: {'changepoint_range': 0.8470000000000001, 'n_changepoints': 30, 'changepoint_prior_scale': 0.17400000000000002, 'seasonality_prior_scale': 2.0}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-15 23:56:09,664] Trial 19 finished with value: 9.924182963215351 and parameters: {'changepoint_range': 0.932, 'n_changepoints': 32, 'changepoint_prior_scale': 0.44, 'seasonality_prior_scale': 11.0}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 25.
# [I 2021-05-15 23:56:15,690] Trial 20 finished with value: 9.942787521807704 and parameters: {'changepoint_range': 0.891, 'n_changepoints': 28, 'changepoint_prior_scale': 0.299, 'seasonality_prior_scale': 7.300000000000001}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 12.
# [I 2021-05-15 23:56:20,289] Trial 21 finished with value: 9.833132159055411 and parameters: {'changepoint_range': 0.8450000000000001, 'n_changepoints': 20, 'changepoint_prior_scale': 0.152, 'seasonality_prior_scale': 6.800000000000001}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 19.
# [I 2021-05-15 23:56:25,375] Trial 22 finished with value: 9.888861079937906 and parameters: {'changepoint_range': 0.884, 'n_changepoints': 29, 'changepoint_prior_scale': 0.23800000000000002, 'seasonality_prior_scale': 8.0}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 13.
# [I 2021-05-15 23:56:30,479] Trial 23 finished with value: 9.825118116865195 and parameters: {'changepoint_range': 0.809, 'n_changepoints': 35, 'changepoint_prior_scale': 0.17, 'seasonality_prior_scale': 12.9}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 12.
# [I 2021-05-15 23:56:35,219] Trial 24 finished with value: 9.827620780679041 and parameters: {'changepoint_range': 0.9470000000000001, 'n_changepoints': 27, 'changepoint_prior_scale': 0.16, 'seasonality_prior_scale': 13.5}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 2.
# [I 2021-05-15 23:56:38,780] Trial 25 finished with value: 10.101276596917904 and parameters: {'changepoint_range': 0.887, 'n_changepoints': 33, 'changepoint_prior_scale': 0.035, 'seasonality_prior_scale': 12.100000000000001}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 24.
# [I 2021-05-15 23:56:46,096] Trial 26 finished with value: 9.859715416325127 and parameters: {'changepoint_range': 0.918, 'n_changepoints': 31, 'changepoint_prior_scale': 0.294, 'seasonality_prior_scale': 1.8}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 12.
# [I 2021-05-15 23:56:50,481] Trial 27 finished with value: 9.833598486441165 and parameters: {'changepoint_range': 0.8520000000000001, 'n_changepoints': 29, 'changepoint_prior_scale': 0.15, 'seasonality_prior_scale': 13.3}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 1.
# [I 2021-05-15 23:56:54,745] Trial 28 finished with value: 10.102076863868902 and parameters: {'changepoint_range': 0.901, 'n_changepoints': 22, 'changepoint_prior_scale': 0.026000000000000002, 'seasonality_prior_scale': 9.1}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-15 23:57:01,200] Trial 29 finished with value: 9.951086026829497 and parameters: {'changepoint_range': 0.8160000000000001, 'n_changepoints': 22, 'changepoint_prior_scale': 0.443, 'seasonality_prior_scale': 9.8}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 3.
# [I 2021-05-15 23:57:04,716] Trial 30 finished with value: 10.10227478913115 and parameters: {'changepoint_range': 0.8330000000000001, 'n_changepoints': 32, 'changepoint_prior_scale': 0.054, 'seasonality_prior_scale': 18.900000000000002}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 5.
# [I 2021-05-15 23:57:08,721] Trial 31 finished with value: 10.102364936940372 and parameters: {'changepoint_range': 0.8700000000000001, 'n_changepoints': 29, 'changepoint_prior_scale': 0.074, 'seasonality_prior_scale': 5.4}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 9.
# [I 2021-05-15 23:57:12,787] Trial 32 finished with value: 10.12544661863597 and parameters: {'changepoint_range': 0.897, 'n_changepoints': 20, 'changepoint_prior_scale': 0.125, 'seasonality_prior_scale': 14.0}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-15 23:57:19,898] Trial 33 finished with value: 9.909503549958593 and parameters: {'changepoint_range': 0.8340000000000001, 'n_changepoints': 26, 'changepoint_prior_scale': 0.462, 'seasonality_prior_scale': 23.3}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using -1.
# [I 2021-05-15 23:57:23,599] Trial 34 finished with value: 10.102456826775242 and parameters: {'changepoint_range': 0.885, 'n_changepoints': 28, 'changepoint_prior_scale': 0.008, 'seasonality_prior_scale': 24.5}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 23.
# [I 2021-05-15 23:57:29,945] Trial 35 finished with value: 9.92380274503829 and parameters: {'changepoint_range': 0.886, 'n_changepoints': 32, 'changepoint_prior_scale': 0.281, 'seasonality_prior_scale': 22.1}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 5.
# [I 2021-05-15 23:57:33,622] Trial 36 finished with value: 10.099322851010623 and parameters: {'changepoint_range': 0.888, 'n_changepoints': 31, 'changepoint_prior_scale': 0.075, 'seasonality_prior_scale': 11.3}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 18.
# [I 2021-05-15 23:57:38,812] Trial 37 finished with value: 9.867934600399765 and parameters: {'changepoint_range': 0.904, 'n_changepoints': 21, 'changepoint_prior_scale': 0.22, 'seasonality_prior_scale': 5.0}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 3.
# [I 2021-05-15 23:57:42,326] Trial 38 finished with value: 10.102305114030612 and parameters: {'changepoint_range': 0.876, 'n_changepoints': 33, 'changepoint_prior_scale': 0.046, 'seasonality_prior_scale': 20.200000000000003}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2021-05-15 23:57:46,132] Trial 39 finished with value: 10.158635295968006 and parameters: {'changepoint_range': 0.885, 'n_changepoints': 29, 'changepoint_prior_scale': 0.1, 'seasonality_prior_scale': 11.5}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 0.
# [I 2021-05-15 23:57:49,460] Trial 40 finished with value: 10.102004630020337 and parameters: {'changepoint_range': 0.8440000000000001, 'n_changepoints': 20, 'changepoint_prior_scale': 0.016, 'seasonality_prior_scale': 11.9}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 15.
# [I 2021-05-15 23:57:54,780] Trial 41 finished with value: 9.831486117739711 and parameters: {'changepoint_range': 0.912, 'n_changepoints': 28, 'changepoint_prior_scale': 0.193, 'seasonality_prior_scale': 5.0}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-15 23:58:02,040] Trial 42 finished with value: 10.008532112091277 and parameters: {'changepoint_range': 0.926, 'n_changepoints': 29, 'changepoint_prior_scale': 0.392, 'seasonality_prior_scale': 21.400000000000002}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 25.
# [I 2021-05-15 23:58:08,751] Trial 43 finished with value: 9.964295309117416 and parameters: {'changepoint_range': 0.891, 'n_changepoints': 32, 'changepoint_prior_scale': 0.308, 'seasonality_prior_scale': 1.5}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 19.
# [I 2021-05-15 23:58:16,067] Trial 44 finished with value: 9.873036748558894 and parameters: {'changepoint_range': 0.913, 'n_changepoints': 22, 'changepoint_prior_scale': 0.23, 'seasonality_prior_scale': 13.3}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 6.
# [I 2021-05-15 23:58:19,574] Trial 45 finished with value: 10.094072908685742 and parameters: {'changepoint_range': 0.873, 'n_changepoints': 33, 'changepoint_prior_scale': 0.08800000000000001, 'seasonality_prior_scale': 1.3}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 18.
# [I 2021-05-15 23:58:24,752] Trial 46 finished with value: 9.886941304691742 and parameters: {'changepoint_range': 0.928, 'n_changepoints': 31, 'changepoint_prior_scale': 0.229, 'seasonality_prior_scale': 11.0}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 3.
# [I 2021-05-15 23:58:28,267] Trial 47 finished with value: 10.103087467520233 and parameters: {'changepoint_range': 0.8170000000000001, 'n_changepoints': 25, 'changepoint_prior_scale': 0.048, 'seasonality_prior_scale': 18.2}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-15 23:58:33,654] Trial 48 finished with value: 9.947307425161757 and parameters: {'changepoint_range': 0.811, 'n_changepoints': 23, 'changepoint_prior_scale': 0.28700000000000003, 'seasonality_prior_scale': 8.0}. Best is trial 18 with value: 9.767208633388739.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 14.
# [I 2021-05-15 23:58:38,870] Trial 49 finished with value: 9.766385209386987 and parameters: {'changepoint_range': 0.899, 'n_changepoints': 32, 'changepoint_prior_scale': 0.17600000000000002, 'seasonality_prior_scale': 3.2}. Best is trial 49 with value: 9.766385209386987.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 16.
# [I 2021-05-15 23:58:44,360] Trial 50 finished with value: 9.834281748182887 and parameters: {'changepoint_range': 0.922, 'n_changepoints': 32, 'changepoint_prior_scale': 0.197, 'seasonality_prior_scale': 21.8}. Best is trial 49 with value: 9.766385209386987.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-15 23:58:49,853] Trial 51 finished with value: 9.996682702112373 and parameters: {'changepoint_range': 0.8570000000000001, 'n_changepoints': 24, 'changepoint_prior_scale': 0.41500000000000004, 'seasonality_prior_scale': 18.7}. Best is trial 49 with value: 9.766385209386987.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 8.
# [I 2021-05-15 23:58:54,112] Trial 52 finished with value: 10.12129864695254 and parameters: {'changepoint_range': 0.876, 'n_changepoints': 30, 'changepoint_prior_scale': 0.107, 'seasonality_prior_scale': 22.5}. Best is trial 49 with value: 9.766385209386987.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-15 23:59:00,545] Trial 53 finished with value: 10.016066574938197 and parameters: {'changepoint_range': 0.9450000000000001, 'n_changepoints': 25, 'changepoint_prior_scale': 0.433, 'seasonality_prior_scale': 8.4}. Best is trial 49 with value: 9.766385209386987.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2021-05-15 23:59:04,276] Trial 54 finished with value: 10.143085155432479 and parameters: {'changepoint_range': 0.803, 'n_changepoints': 20, 'changepoint_prior_scale': 0.093, 'seasonality_prior_scale': 2.6}. Best is trial 49 with value: 9.766385209386987.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 18.
# [I 2021-05-15 23:59:10,846] Trial 55 finished with value: 9.878209263684552 and parameters: {'changepoint_range': 0.8380000000000001, 'n_changepoints': 34, 'changepoint_prior_scale': 0.229, 'seasonality_prior_scale': 4.1}. Best is trial 49 with value: 9.766385209386987.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 0.
# [I 2021-05-15 23:59:13,936] Trial 56 finished with value: 10.103338073972257 and parameters: {'changepoint_range': 0.922, 'n_changepoints': 26, 'changepoint_prior_scale': 0.013000000000000001, 'seasonality_prior_scale': 21.6}. Best is trial 49 with value: 9.766385209386987.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 14.
# [I 2021-05-15 23:59:18,065] Trial 57 finished with value: 9.76545938581077 and parameters: {'changepoint_range': 0.8410000000000001, 'n_changepoints': 31, 'changepoint_prior_scale': 0.178, 'seasonality_prior_scale': 20.1}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 23.
# [I 2021-05-15 23:59:24,625] Trial 58 finished with value: 9.95270183428893 and parameters: {'changepoint_range': 0.927, 'n_changepoints': 28, 'changepoint_prior_scale': 0.28, 'seasonality_prior_scale': 3.9000000000000004}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 21.
# [I 2021-05-15 23:59:29,542] Trial 59 finished with value: 9.935817887794347 and parameters: {'changepoint_range': 0.8570000000000001, 'n_changepoints': 26, 'changepoint_prior_scale': 0.256, 'seasonality_prior_scale': 22.400000000000002}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-15 23:59:36,986] Trial 60 finished with value: 10.015764628171182 and parameters: {'changepoint_range': 0.8450000000000001, 'n_changepoints': 26, 'changepoint_prior_scale': 0.397, 'seasonality_prior_scale': 10.9}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 23.
# [I 2021-05-15 23:59:43,295] Trial 61 finished with value: 9.92740952123417 and parameters: {'changepoint_range': 0.8270000000000001, 'n_changepoints': 33, 'changepoint_prior_scale': 0.28500000000000003, 'seasonality_prior_scale': 2.4000000000000004}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-15 23:59:50,067] Trial 62 finished with value: 9.946076785070423 and parameters: {'changepoint_range': 0.9490000000000001, 'n_changepoints': 23, 'changepoint_prior_scale': 0.308, 'seasonality_prior_scale': 9.8}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-15 23:59:57,453] Trial 63 finished with value: 9.94250938202026 and parameters: {'changepoint_range': 0.921, 'n_changepoints': 30, 'changepoint_prior_scale': 0.41100000000000003, 'seasonality_prior_scale': 7.9}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:00:02,920] Trial 64 finished with value: 9.878713340496049 and parameters: {'changepoint_range': 0.8410000000000001, 'n_changepoints': 29, 'changepoint_prior_scale': 0.47000000000000003, 'seasonality_prior_scale': 18.0}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 19.
# [I 2021-05-16 00:00:08,001] Trial 65 finished with value: 9.873043655633996 and parameters: {'changepoint_range': 0.8390000000000001, 'n_changepoints': 21, 'changepoint_prior_scale': 0.23, 'seasonality_prior_scale': 24.400000000000002}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 1.
# [I 2021-05-16 00:00:11,217] Trial 66 finished with value: 10.102111267172216 and parameters: {'changepoint_range': 0.902, 'n_changepoints': 23, 'changepoint_prior_scale': 0.024, 'seasonality_prior_scale': 23.900000000000002}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:00:17,694] Trial 67 finished with value: 9.85501075749141 and parameters: {'changepoint_range': 0.929, 'n_changepoints': 33, 'changepoint_prior_scale': 0.482, 'seasonality_prior_scale': 15.4}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 3.
# [I 2021-05-16 00:00:21,234] Trial 68 finished with value: 10.100796411746895 and parameters: {'changepoint_range': 0.9400000000000001, 'n_changepoints': 22, 'changepoint_prior_scale': 0.057, 'seasonality_prior_scale': 9.9}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:00:27,076] Trial 69 finished with value: 9.967594242021628 and parameters: {'changepoint_range': 0.915, 'n_changepoints': 25, 'changepoint_prior_scale': 0.32, 'seasonality_prior_scale': 1.2}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:00:32,827] Trial 70 finished with value: 10.00848235484617 and parameters: {'changepoint_range': 0.882, 'n_changepoints': 25, 'changepoint_prior_scale': 0.45, 'seasonality_prior_scale': 23.6}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:00:38,364] Trial 71 finished with value: 10.015725895150373 and parameters: {'changepoint_range': 0.8580000000000001, 'n_changepoints': 26, 'changepoint_prior_scale': 0.449, 'seasonality_prior_scale': 2.4000000000000004}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 2.
# [I 2021-05-16 00:00:41,810] Trial 72 finished with value: 10.10231973991487 and parameters: {'changepoint_range': 0.861, 'n_changepoints': 22, 'changepoint_prior_scale': 0.044000000000000004, 'seasonality_prior_scale': 19.8}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:00:49,329] Trial 73 finished with value: 10.01376782926764 and parameters: {'changepoint_range': 0.8450000000000001, 'n_changepoints': 29, 'changepoint_prior_scale': 0.44, 'seasonality_prior_scale': 22.200000000000003}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 1.
# [I 2021-05-16 00:00:52,539] Trial 74 finished with value: 10.100699955941554 and parameters: {'changepoint_range': 0.89, 'n_changepoints': 30, 'changepoint_prior_scale': 0.029, 'seasonality_prior_scale': 8.100000000000001}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:00:58,910] Trial 75 finished with value: 10.00971506063436 and parameters: {'changepoint_range': 0.904, 'n_changepoints': 23, 'changepoint_prior_scale': 0.402, 'seasonality_prior_scale': 13.4}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 2.
# [I 2021-05-16 00:01:02,595] Trial 76 finished with value: 10.12002488561187 and parameters: {'changepoint_range': 0.914, 'n_changepoints': 22, 'changepoint_prior_scale': 0.042, 'seasonality_prior_scale': 12.600000000000001}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 7.
# [I 2021-05-16 00:01:06,887] Trial 77 finished with value: 10.162595221377863 and parameters: {'changepoint_range': 0.879, 'n_changepoints': 31, 'changepoint_prior_scale': 0.10300000000000001, 'seasonality_prior_scale': 17.1}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:01:12,960] Trial 78 finished with value: 9.872007337561568 and parameters: {'changepoint_range': 0.919, 'n_changepoints': 20, 'changepoint_prior_scale': 0.482, 'seasonality_prior_scale': 24.5}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 14.
# [I 2021-05-16 00:01:19,830] Trial 79 finished with value: 9.7684001346424 and parameters: {'changepoint_range': 0.883, 'n_changepoints': 21, 'changepoint_prior_scale': 0.17300000000000001, 'seasonality_prior_scale': 1.4}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 5.
# [I 2021-05-16 00:01:23,255] Trial 80 finished with value: 10.103053751719514 and parameters: {'changepoint_range': 0.92, 'n_changepoints': 23, 'changepoint_prior_scale': 0.07200000000000001, 'seasonality_prior_scale': 17.8}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 21.
# [I 2021-05-16 00:01:28,301] Trial 81 finished with value: 9.919460432444243 and parameters: {'changepoint_range': 0.808, 'n_changepoints': 24, 'changepoint_prior_scale': 0.256, 'seasonality_prior_scale': 24.900000000000002}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 25.
# [I 2021-05-16 00:01:35,183] Trial 82 finished with value: 9.957157125306484 and parameters: {'changepoint_range': 0.8220000000000001, 'n_changepoints': 27, 'changepoint_prior_scale': 0.301, 'seasonality_prior_scale': 3.3000000000000003}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 23.
# [I 2021-05-16 00:01:41,259] Trial 83 finished with value: 9.932688626144358 and parameters: {'changepoint_range': 0.8430000000000001, 'n_changepoints': 31, 'changepoint_prior_scale': 0.276, 'seasonality_prior_scale': 21.200000000000003}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:01:46,983] Trial 84 finished with value: 9.890393196043457 and parameters: {'changepoint_range': 0.887, 'n_changepoints': 22, 'changepoint_prior_scale': 0.308, 'seasonality_prior_scale': 22.3}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 21.
# [I 2021-05-16 00:01:52,323] Trial 85 finished with value: 9.910128706192351 and parameters: {'changepoint_range': 0.878, 'n_changepoints': 30, 'changepoint_prior_scale': 0.253, 'seasonality_prior_scale': 22.900000000000002}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 13.
# [I 2021-05-16 00:01:56,538] Trial 86 finished with value: 9.801809796256396 and parameters: {'changepoint_range': 0.8620000000000001, 'n_changepoints': 28, 'changepoint_prior_scale': 0.17200000000000001, 'seasonality_prior_scale': 4.1}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 25.
# [I 2021-05-16 00:02:01,947] Trial 87 finished with value: 9.960041289239696 and parameters: {'changepoint_range': 0.9, 'n_changepoints': 34, 'changepoint_prior_scale': 0.307, 'seasonality_prior_scale': 21.3}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using -1.
# [I 2021-05-16 00:02:05,081] Trial 88 finished with value: 10.102099397461185 and parameters: {'changepoint_range': 0.8320000000000001, 'n_changepoints': 34, 'changepoint_prior_scale': 0.005, 'seasonality_prior_scale': 6.4}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:02:11,334] Trial 89 finished with value: 9.985709050207243 and parameters: {'changepoint_range': 0.8190000000000001, 'n_changepoints': 34, 'changepoint_prior_scale': 0.456, 'seasonality_prior_scale': 15.0}. Best is trial 57 with value: 9.76545938581077.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# ...
# [I 2021-05-16 00:08:58,950] Trial 189 finished with value: 10.094472917287451 and parameters: {'changepoint_range': 0.8490000000000001, 'n_changepoints': 20, 'changepoint_prior_scale': 0.069, 'seasonality_prior_scale': 19.5}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 24.
# [I 2021-05-16 00:09:03,303] Trial 190 finished with value: 9.943184186235673 and parameters: {'changepoint_range': 0.925, 'n_changepoints': 30, 'changepoint_prior_scale': 0.28800000000000003, 'seasonality_prior_scale': 22.8}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:09:07,846] Trial 191 finished with value: 9.993108960150133 and parameters: {'changepoint_range': 0.907, 'n_changepoints': 27, 'changepoint_prior_scale': 0.354, 'seasonality_prior_scale': 16.4}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 31.
# [I 2021-05-16 00:09:12,068] Trial 192 finished with value: 10.018648729284902 and parameters: {'changepoint_range': 0.803, 'n_changepoints': 32, 'changepoint_prior_scale': 0.374, 'seasonality_prior_scale': 10.3}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:09:16,591] Trial 193 finished with value: 9.769372095544105 and parameters: {'changepoint_range': 0.888, 'n_changepoints': 23, 'changepoint_prior_scale': 0.495, 'seasonality_prior_scale': 15.100000000000001}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:09:21,171] Trial 194 finished with value: 10.020080170739703 and parameters: {'changepoint_range': 0.8300000000000001, 'n_changepoints': 35, 'changepoint_prior_scale': 0.427, 'seasonality_prior_scale': 9.200000000000001}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 23.
# [I 2021-05-16 00:09:25,625] Trial 195 finished with value: 9.936274604818257 and parameters: {'changepoint_range': 0.899, 'n_changepoints': 34, 'changepoint_prior_scale': 0.28, 'seasonality_prior_scale': 15.8}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:09:30,075] Trial 196 finished with value: 9.904381240146327 and parameters: {'changepoint_range': 0.8700000000000001, 'n_changepoints': 35, 'changepoint_prior_scale': 0.467, 'seasonality_prior_scale': 1.6}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 5.
# [I 2021-05-16 00:09:32,470] Trial 197 finished with value: 10.102102034318989 and parameters: {'changepoint_range': 0.867, 'n_changepoints': 25, 'changepoint_prior_scale': 0.078, 'seasonality_prior_scale': 8.100000000000001}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 12.
# [I 2021-05-16 00:09:35,586] Trial 198 finished with value: 9.831060202595564 and parameters: {'changepoint_range': 0.908, 'n_changepoints': 27, 'changepoint_prior_scale': 0.155, 'seasonality_prior_scale': 23.1}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:09:39,800] Trial 199 finished with value: 10.017608143513973 and parameters: {'changepoint_range': 0.905, 'n_changepoints': 24, 'changepoint_prior_scale': 0.397, 'seasonality_prior_scale': 25.0}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:09:44,713] Trial 200 finished with value: 10.011412528504065 and parameters: {'changepoint_range': 0.906, 'n_changepoints': 27, 'changepoint_prior_scale': 0.398, 'seasonality_prior_scale': 13.8}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:09:49,802] Trial 201 finished with value: 9.868795249902668 and parameters: {'changepoint_range': 0.886, 'n_changepoints': 35, 'changepoint_prior_scale': 0.47200000000000003, 'seasonality_prior_scale': 15.200000000000001}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 17.
# [I 2021-05-16 00:09:53,006] Trial 202 finished with value: 9.8656176947931 and parameters: {'changepoint_range': 0.8340000000000001, 'n_changepoints': 27, 'changepoint_prior_scale': 0.218, 'seasonality_prior_scale': 8.9}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 4.
# [I 2021-05-16 00:09:55,402] Trial 203 finished with value: 10.10066488147305 and parameters: {'changepoint_range': 0.891, 'n_changepoints': 21, 'changepoint_prior_scale': 0.058, 'seasonality_prior_scale': 24.3}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:09:59,627] Trial 204 finished with value: 9.772100557777359 and parameters: {'changepoint_range': 0.9430000000000001, 'n_changepoints': 26, 'changepoint_prior_scale': 0.494, 'seasonality_prior_scale': 18.3}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:10:03,496] Trial 205 finished with value: 10.019567899296202 and parameters: {'changepoint_range': 0.9390000000000001, 'n_changepoints': 25, 'changepoint_prior_scale': 0.422, 'seasonality_prior_scale': 15.5}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 14.
# [I 2021-05-16 00:10:06,867] Trial 206 finished with value: 9.766359332779647 and parameters: {'changepoint_range': 0.927, 'n_changepoints': 21, 'changepoint_prior_scale': 0.17600000000000002, 'seasonality_prior_scale': 11.3}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using -1.
# [I 2021-05-16 00:10:09,057] Trial 207 finished with value: 10.104644286894564 and parameters: {'changepoint_range': 0.921, 'n_changepoints': 23, 'changepoint_prior_scale': 0.002, 'seasonality_prior_scale': 10.3}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:10:13,774] Trial 208 finished with value: 10.002810773812556 and parameters: {'changepoint_range': 0.9390000000000001, 'n_changepoints': 22, 'changepoint_prior_scale': 0.375, 'seasonality_prior_scale': 23.8}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 13.
# [I 2021-05-16 00:10:17,552] Trial 209 finished with value: 9.800100246307226 and parameters: {'changepoint_range': 0.8370000000000001, 'n_changepoints': 22, 'changepoint_prior_scale': 0.17200000000000001, 'seasonality_prior_scale': 8.0}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 23.
# [I 2021-05-16 00:10:22,337] Trial 210 finished with value: 9.864813115939802 and parameters: {'changepoint_range': 0.8400000000000001, 'n_changepoints': 27, 'changepoint_prior_scale': 0.28, 'seasonality_prior_scale': 1.1}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:10:26,525] Trial 211 finished with value: 10.000465328999459 and parameters: {'changepoint_range': 0.927, 'n_changepoints': 22, 'changepoint_prior_scale': 0.382, 'seasonality_prior_scale': 2.9000000000000004}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 9.
# [I 2021-05-16 00:10:29,368] Trial 212 finished with value: 10.043191333177838 and parameters: {'changepoint_range': 0.915, 'n_changepoints': 25, 'changepoint_prior_scale': 0.121, 'seasonality_prior_scale': 19.2}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:10:33,548] Trial 213 finished with value: 9.984507595404624 and parameters: {'changepoint_range': 0.808, 'n_changepoints': 27, 'changepoint_prior_scale': 0.451, 'seasonality_prior_scale': 22.8}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 28.
# [I 2021-05-16 00:10:38,307] Trial 214 finished with value: 9.974441854880588 and parameters: {'changepoint_range': 0.8700000000000001, 'n_changepoints': 33, 'changepoint_prior_scale': 0.334, 'seasonality_prior_scale': 7.300000000000001}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# [I 2021-05-16 00:10:43,722] Trial 215 finished with value: 9.948538335728479 and parameters: {'changepoint_range': 0.8530000000000001, 'n_changepoints': 34, 'changepoint_prior_scale': 0.442, 'seasonality_prior_scale': 24.0}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 4.
# [I 2021-05-16 00:10:46,070] Trial 216 finished with value: 10.105548758892713 and parameters: {'changepoint_range': 0.8330000000000001, 'n_changepoints': 22, 'changepoint_prior_scale': 0.062, 'seasonality_prior_scale': 12.5}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 20.
# [I 2021-05-16 00:10:50,230] Trial 217 finished with value: 9.896713141210329 and parameters: {'changepoint_range': 0.8380000000000001, 'n_changepoints': 35, 'changepoint_prior_scale': 0.246, 'seasonality_prior_scale': 18.3}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using -1.
# [I 2021-05-16 00:10:52,344] Trial 218 finished with value: 10.094033641007956 and parameters: {'changepoint_range': 0.95, 'n_changepoints': 26, 'changepoint_prior_scale': 0.011, 'seasonality_prior_scale': 1.3}. Best is trial 145 with value: 9.761791000098691.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 3.
# [I 2021-05-16 00:10:54,721] Trial 219 finished with value: 10.102211194578292 and parameters: {'changepoint_range': 0.871, 'n_changepoints': 30, 'changepoint_prior_scale': 0.053000000000000005, 'seasonality_prior_scale': 6.2}. Best is trial 145 with value: 9.761791000098691.
# CPU times: user 16min 21s, sys: 20.8 s, total: 16min 42s
# Wall time: 16min 40s

# %%
# fit_model
best_model = Prophet(
    changepoint_range = study.best_params['changepoint_prior_scale'],
    n_changepoints=study.best_params['n_changepoints'],
    seasonality_prior_scale = study.best_params['seasonality_prior_scale'],
    changepoint_prior_scale=study.best_params['changepoint_prior_scale'],
)

# %%
best_model.fit(df_train)
feature_test = best_model.make_future_dataframe(periods=len(df_valid)+len(df_test), freq='M')

forecast_test = best_model.predict(feature_test)
forecast_test_plot = best_model.plot(forecast_test)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 15.
