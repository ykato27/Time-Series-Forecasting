# %% [markdown]
# ## 時系列分析における回帰モデルの予測

# %%
# %load_ext lab_black

# %%
# ライブラリーのインポート
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from matplotlib import pylab as plt

# %matplotlib inline

# 統計モデル
import statsmodels.api as sm

# GBDT
from sklearn.ensemble import GradientBoostingRegressor

# グラフを横長にする
from matplotlib.pylab import rcParams

rcParams["figure.figsize"] = 15, 6

# %%
# https://stat.ethz.ch/R-manual/R-devel/library/datasets/html/AirPassengers.html
df = pd.read_csv("../../data/AirPassengers.csv")

# float型に変換
df["#Passengers"] = df["#Passengers"].astype("float64")
df = df.rename(columns={"#Passengers": "Passengers"})

# datetime型にしてインデックスにする
df.Month = pd.to_datetime(df.Month)
df = df.set_index("Month")

# データの中身を確認
df.head()
# Out:
#             Passengers
# Month
# 1949-01-01       112.0
# 1949-02-01       118.0
# 1949-03-01       132.0
# 1949-04-01       129.0
# 1949-05-01       121.0

# %% [markdown]
# ## コレログラム

# %%
#  自己相関のグラフ
fig = plt.figure(figsize=(12, 8))
fig = sm.graphics.tsa.plot_acf(df["Passengers"], lags=30)

# %%
# 偏自己相関を可視化する
fig = plt.figure(figsize=(12, 8))
fig = sm.graphics.tsa.plot_pacf(df["Passengers"], lags=30)

# %% [markdown]
# ## 過去12ヶ月の履歴を作成

# %%
for i in range(1, 13):
    df["shift%s" % i] = df["Passengers"].shift(i)

pd.concat([df.head(13), df.tail(3)], axis=0, sort=False)
# Out:
#             Passengers  shift1  shift2  shift3  shift4  shift5  shift6  \
# Month
# 1949-01-01       112.0     NaN     NaN     NaN     NaN     NaN     NaN
# 1949-02-01       118.0   112.0     NaN     NaN     NaN     NaN     NaN
# 1949-03-01       132.0   118.0   112.0     NaN     NaN     NaN     NaN
# 1949-04-01       129.0   132.0   118.0   112.0     NaN     NaN     NaN
# 1949-05-01       121.0   129.0   132.0   118.0   112.0     NaN     NaN
# 1949-06-01       135.0   121.0   129.0   132.0   118.0   112.0     NaN
# 1949-07-01       148.0   135.0   121.0   129.0   132.0   118.0   112.0
# 1949-08-01       148.0   148.0   135.0   121.0   129.0   132.0   118.0
# 1949-09-01       136.0   148.0   148.0   135.0   121.0   129.0   132.0
# 1949-10-01       119.0   136.0   148.0   148.0   135.0   121.0   129.0
# 1949-11-01       104.0   119.0   136.0   148.0   148.0   135.0   121.0
# 1949-12-01       118.0   104.0   119.0   136.0   148.0   148.0   135.0
# 1950-01-01       115.0   118.0   104.0   119.0   136.0   148.0   148.0
# 1960-10-01       461.0   508.0   606.0   622.0   535.0   472.0   461.0
# 1960-11-01       390.0   461.0   508.0   606.0   622.0   535.0   472.0
# 1960-12-01       432.0   390.0   461.0   508.0   606.0   622.0   535.0
#
#             shift7  shift8  shift9  shift10  shift11  shift12
# Month
# 1949-01-01     NaN     NaN     NaN      NaN      NaN      NaN
# 1949-02-01     NaN     NaN     NaN      NaN      NaN      NaN
# 1949-03-01     NaN     NaN     NaN      NaN      NaN      NaN
# 1949-04-01     NaN     NaN     NaN      NaN      NaN      NaN
# 1949-05-01     NaN     NaN     NaN      NaN      NaN      NaN
# 1949-06-01     NaN     NaN     NaN      NaN      NaN      NaN
# 1949-07-01     NaN     NaN     NaN      NaN      NaN      NaN
# 1949-08-01   112.0     NaN     NaN      NaN      NaN      NaN
# 1949-09-01   118.0   112.0     NaN      NaN      NaN      NaN
# 1949-10-01   132.0   118.0   112.0      NaN      NaN      NaN
# 1949-11-01   129.0   132.0   118.0    112.0      NaN      NaN
# 1949-12-01   121.0   129.0   132.0    118.0    112.0      NaN
# 1950-01-01   135.0   121.0   129.0    132.0    118.0    112.0
# 1960-10-01   419.0   391.0   417.0    405.0    362.0    407.0
# 1960-11-01   461.0   419.0   391.0    417.0    405.0    362.0
# 1960-12-01   472.0   461.0   419.0    391.0    417.0    405.0

# %% [markdown]
# ## 1回差分の作成

# %%
df["deriv1"] = df["shift1"].diff(1)
df[["Passengers", "deriv1"]].head()
# Out:
#             Passengers  deriv1
# Month
# 1949-01-01       112.0     NaN
# 1949-02-01       118.0     NaN
# 1949-03-01       132.0     6.0
# 1949-04-01       129.0    14.0
# 1949-05-01       121.0    -3.0

# %% [markdown]
# ## 2回差分の作成

# %%
df["deriv2"] = df["shift1"].diff(1).diff(1)
df[["Passengers", "deriv2"]].head()
# Out:
#             Passengers  deriv2
# Month
# 1949-01-01       112.0     NaN
# 1949-02-01       118.0     NaN
# 1949-03-01       132.0     NaN
# 1949-04-01       129.0     8.0
# 1949-05-01       121.0   -17.0

# %% [markdown]
# ## 基礎統計量の作成

# %%
df["mean"] = df["shift1"].rolling(12).mean()
df["median"] = df["shift1"].rolling(12).median()
df["max"] = df["shift1"].rolling(12).max()
df["min"] = df["shift1"].rolling(12).min()
df[["Passengers", "mean", "median", "max", "min"]][12:24]
# Out:
#             Passengers        mean  median    max    min
# Month
# 1950-01-01       115.0  126.666667   125.0  148.0  104.0
# 1950-02-01       126.0  126.916667   125.0  148.0  104.0
# 1950-03-01       141.0  127.583333   127.5  148.0  104.0
# 1950-04-01       135.0  128.333333   127.5  148.0  104.0
# 1950-05-01       125.0  128.833333   130.5  148.0  104.0
# 1950-06-01       149.0  129.166667   130.5  148.0  104.0
# 1950-07-01       170.0  130.333333   130.5  149.0  104.0
# 1950-08-01       170.0  132.166667   130.5  170.0  104.0
# 1950-09-01       158.0  134.000000   130.5  170.0  104.0
# 1950-10-01       133.0  135.833333   130.5  170.0  104.0
# 1950-11-01       114.0  137.000000   134.0  170.0  104.0
# 1950-12-01       140.0  137.833333   134.0  170.0  114.0

# %% [markdown]
# ## 欠損値データの削除

# %%
df = df.dropna()
df.head()
# Out:
#             Passengers  shift1  shift2  shift3  shift4  shift5  shift6  \
# Month
# 1950-01-01       115.0   118.0   104.0   119.0   136.0   148.0   148.0
# 1950-02-01       126.0   115.0   118.0   104.0   119.0   136.0   148.0
# 1950-03-01       141.0   126.0   115.0   118.0   104.0   119.0   136.0
# 1950-04-01       135.0   141.0   126.0   115.0   118.0   104.0   119.0
# 1950-05-01       125.0   135.0   141.0   126.0   115.0   118.0   104.0
#
#             shift7  shift8  shift9  shift10  shift11  shift12  deriv1  deriv2  \
# Month
# 1950-01-01   135.0   121.0   129.0    132.0    118.0    112.0    14.0    29.0
# 1950-02-01   148.0   135.0   121.0    129.0    132.0    118.0    -3.0   -17.0
# 1950-03-01   148.0   148.0   135.0    121.0    129.0    132.0    11.0    14.0
# 1950-04-01   136.0   148.0   148.0    135.0    121.0    129.0    15.0     4.0
# 1950-05-01   119.0   136.0   148.0    148.0    135.0    121.0    -6.0   -21.0
#
#                   mean  median    max    min
# Month
# 1950-01-01  126.666667   125.0  148.0  104.0
# 1950-02-01  126.916667   125.0  148.0  104.0
# 1950-03-01  127.583333   127.5  148.0  104.0
# 1950-04-01  128.333333   127.5  148.0  104.0
# 1950-05-01  128.833333   130.5  148.0  104.0

# %% [markdown]
# ## モデルの学習

# %%
x = df.drop("Passengers", axis=1)
y = df["Passengers"]

# 学習データと評価データを作成
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)

# データを標準化
sc = StandardScaler()
sc.fit(x_train)  # 学習用データで標準化
x_train_std = sc.transform(x_train)
x_test_std = sc.transform(x_test)

# %%
# モデルの学習
GBDT = GradientBoostingRegressor()
GBDT.fit(x_train_std, y_train)

# 予測
y_pred = GBDT.predict(x_test_std)

# %%
y_ = np.concatenate([np.array([None for i in range(len(y_train))]), y_pred])
y_ = pd.DataFrame(y_, index=df.index)

plt.figure(figsize=(10, 5))
plt.plot(y, label="original")
plt.plot(y_, "--", label="predict")
plt.legend()
